# %% [markdown]
# limpiar col names Sheet

# %%
import pandas as pd
import glob
import re
import os

# %% [markdown]
# Separate Sheet

# %% [markdown]
# Generate simple dataset flujograma

# %%
def simple_dataset_flujograma(result_df_list, file_path):
    """Genera dataset simplificado extrayendo intersección y tipo de día del filename"""
    import os
    
    # Extraer información del nombre del archivo
    basename = os.path.basename(file_path)
    name_without_ext = os.path.splitext(basename)[0]
    
    codigo = ''
    interseccion = ''
    
    if '_' in name_without_ext:
        parts = name_without_ext.split('_')
        
        # Si el primer elemento parece un código (números o letras+números cortos)
        first_part = parts[0]
        if len(first_part) <= 6 and (first_part.isdigit() or first_part.isalnum()):
            # Formato tipo: 58_SS77-01_Av. Rosa Lozano...
            codigo = first_part
            if len(parts) > 2:
                interseccion = '_'.join(parts[1:])  # Incluir segunda parte del código
            else:
                interseccion = '_'.join(parts[1:])
        else:
            # Formato tipo: SP01 Av. Los Héroes - Ca. Los Conquistadores_Día_Tipico
            # El código está al inicio sin separador
            codigo_match = re.match(r'^([A-Z]{2,4}\d{1,3})', name_without_ext)
            if codigo_match:
                codigo = codigo_match.group(1)
                interseccion = name_without_ext[len(codigo):].strip()
            else:
                codigo = parts[0] if len(parts) > 0 else ''
                interseccion = '_'.join(parts[1:]) if len(parts) > 1 else name_without_ext
    else:
        # Sin separadores de guión bajo
        codigo_match = re.match(r'^([A-Z]{2,4}\d{1,3})', name_without_ext)
        if codigo_match:
            codigo = codigo_match.group(1)
            interseccion = name_without_ext[len(codigo):].strip()
        else:
            interseccion = name_without_ext
    
    # Verificar si es atípico
    es_atipico = any(word in name_without_ext.lower() for word in ['atípico', 'atipico'])
    dia_tipo = 'Atípico' if es_atipico else 'Típico'
    
    # Limpiar intersección (remover referencias a día)
    palabras_remover = ['día_atípico', 'dia_atipico', 'día_típico', 'dia_tipico', 
                       '_día_', '_dia_', 'día', 'dia']
    
    for palabra in palabras_remover:
        interseccion = interseccion.replace(palabra, '').replace(palabra.capitalize(), '')
    
    # Limpiar puntos extras, guiones bajos y espacios múltiples
    interseccion = interseccion.replace('..', '').replace('_', ' ').strip()
    interseccion = re.sub(r'\s+', ' ', interseccion)
    interseccion = interseccion.strip()
    
    print(f"Archivo parseado: {basename}")
    print(f"  Código: '{codigo}'")
    print(f"  Intersección: '{interseccion}'")
    print(f"  Es atípico: {es_atipico}")
    print(f"  Día tipo: {dia_tipo}")
    
    all_data = []
    
    for df in result_df_list:
        # Crear dataset básico
        simple_data = {}
        
        # Datos del DataFrame
        #simple_data['hora'] = df['hora']
        simple_data['suma_vehiculos'] = df['suma_vehiculos']
        simple_data['sheet_origen'] = df['sheet_origen'].iloc[0] if 'sheet_origen' in df.columns else 'Unknown'
        
        # Información extraída del filename
        #simple_data['codigo'] = codigo
        simple_data['interseccion'] = interseccion
        #simple_data['es_atipico'] = es_atipico
        simple_data['dia_tipo'] = dia_tipo
        #simple_data['filename'] = basename
            
        # Crear DataFrame
        simple_df = pd.DataFrame(simple_data)
        all_data.append(simple_df)
    
    return all_data

# %% [markdown]
# Combinar datasets

# %%
# Retorna un dataframe combinado
def combined_dataset(datasets):
    """Retorna un dataframe combinado con suma_vehiculos por dirección (N,S,E,O)"""
    
    # Concatenar verticalmente primero
    final_df = pd.concat(datasets, axis=0, ignore_index=True)
    
    # Pivotar para tener una columna por cada dirección (sheet_origen)
    pivot_df = final_df.pivot_table(
        index=['interseccion', 'dia_tipo'], 
        columns='sheet_origen', 
        values='suma_vehiculos', 
        aggfunc='first'
    ).reset_index()
    
    # Renombrar las columnas para que tengan el formato deseado
    pivot_df.columns.name = None  # Quitar el nombre del índice de columnas
    
    # Crear nombres de columnas con el formato suma_vehiculos_X
    new_columns = {}
    for col in pivot_df.columns:
        if col in ['N', 'S', 'E', 'O']:
            new_columns[col] = f'suma_vehiculos_{col}'
        else:
            new_columns[col] = col
    
    pivot_df = pivot_df.rename(columns=new_columns)
    
    # Rellenar valores NaN con 0 para direcciones que no existen
    direction_cols = ['suma_vehiculos_N', 'suma_vehiculos_S', 'suma_vehiculos_E', 'suma_vehiculos_O']
    for col in direction_cols:
        if col not in pivot_df.columns:
            pivot_df[col] = 0
        else:
            pivot_df[col] = pivot_df[col].fillna(0)
    
    # Crear secuencia de tiempo cada 15 minutos desde 6:30
    num_rows = len(pivot_df)
    hora_inicio = []
    hora_fin = []
    
    # Empezar desde 6:30 (390 minutos desde medianoche)
    start_minutes = 6 * 60 + 30  # 6:30 = 390 minutos
    
    for i in range(num_rows):
        # Calcular minutos para hora inicio
        inicio_minutes = start_minutes + (i * 15)
        fin_minutes = inicio_minutes + 15
        
        # Convertir a horas y minutos para inicio
        inicio_hours = (inicio_minutes // 60) % 24
        inicio_mins = inicio_minutes % 60
        
        # Convertir a horas y minutos para fin
        fin_hours = (fin_minutes // 60) % 24
        fin_mins = fin_minutes % 60
        
        # Formatear como HH:MM
        hora_inicio_str = f"{inicio_hours:02d}:{inicio_mins:02d}"
        hora_fin_str = f"{fin_hours:02d}:{fin_mins:02d}"
        
        hora_inicio.append(hora_inicio_str)
        hora_fin.append(hora_fin_str)
    
    # Agregar las columnas de tiempo
    pivot_df['hora_inicio'] = hora_inicio
    pivot_df['hora_fin'] = hora_fin
    
    # Reordenar columnas
    columns_order = ['interseccion', 'dia_tipo', 'suma_vehiculos_N', 'suma_vehiculos_S', 
                    'suma_vehiculos_E', 'suma_vehiculos_O', 'hora_inicio', 'hora_fin']
    
    # Solo incluir columnas que existen
    final_columns = [col for col in columns_order if col in pivot_df.columns]
    pivot_df = pivot_df[final_columns]
    
    return pivot_df

# %% [markdown]
# Concatenar archivos excels

# %%
def extract_flujograma(file_path, names_sheet_not):
    """Extrae datos específicos entre coordenadas K42:DJ97 y calcula suma por fila"""
    try:
        all_data = []
        xls = pd.ExcelFile(file_path)
        print(f"Hojas encontradas: {xls.sheet_names}")
       
        
        for sheet_name in xls.sheet_names:
            if sheet_name in names_sheet_not:
                continue
                
            print(f"\nProcesando hoja: {sheet_name}")
            
            # Leer toda la hoja sin header
            df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=None)
            print(f"Forma total: {df_raw.shape}")
  
        
            
            start_row = 41  # K42 (fila 42 en Excel)
            end_row = 96    # K97 (fila 97 en Excel)
            start_col = 10  # K (columna K en Excel)
            end_col = 113   # DJ (columna DJ en Excel - DJ es la columna 114)
                
            if len(df_raw) <= end_row or len(df_raw.columns) <= end_col:
                print(f" Dimensiones insuficientes. Necesario: filas>{end_row}, cols>{end_col}")
                print(f"  Actual: filas={len(df_raw)}, cols={len(df_raw.columns)}")
                continue
            
            # Extraer la región K42:DJ97
            data_region = df_raw.iloc[start_row:end_row+1, start_col:end_col+1].copy()
            print(f"Región extraída: {data_region.shape}")
            
            # Procesar cada fila y calcular suma
            clean_data = []
            
            for i, row_idx in enumerate(range(start_row, end_row+1)):
                excel_row = row_idx + 1  # Convertir a número de fila de Excel
                
                # Obtener la fila completa original para contexto (hora, etc.)
                full_row = df_raw.iloc[row_idx]
                
                # Obtener la región de datos numéricos (K:DJ)
                numeric_region = df_raw.iloc[row_idx, start_col:end_col+1]
                
                # Convertir a numérico y calcular suma
                numeric_values = pd.to_numeric(numeric_region, errors='coerce').fillna(0)
                row_sum = numeric_values.sum()
                
                # Extraer información contextual (primeras columnas)
                hora = str(full_row[0]) if pd.notna(full_row[0]) else ""
                
                # Solo incluir filas que tengan datos válidos
                if row_sum > 0 :
                    clean_data.append({
                        'suma_vehiculos': row_sum,
                        'sheet_origen': sheet_name
                    })
                    
                    # Mostrar algunas filas de ejemplo
                    if i < 3:
                        print(f"  Fila {excel_row}: hora='{hora}', suma={row_sum}")
            if clean_data:
                df_clean = pd.DataFrame(clean_data)
                all_data.append(df_clean)
                print(f" Extraídas {len(clean_data)} filas válidas")
                print(f" Suma total de vehículos: {df_clean['suma_vehiculos'].sum()}")
            else:
                print(f" No se encontraron datos válidos")
        
    

        return all_data
    
    except Exception as e:
        print(f"Error procesando archivo: {e}")
        return None

# %%
def flujograma_concat_excels(path_files: str, name_file: str, list_not):
    """Une todos los archivos Excel de una carpeta, limpia columnas y combina sheets"""
    files = glob.glob(path_files)
    print(f"Archivos encontrados: {len(files)}")
    print("Archivos:", files)
    
    all_combined_data = []

    for file in files:

        print(f"\nProcesando archivo: {file}")
        
        # Usar la función separate_excel_sheets para cada archivo
        result_df_list = extract_flujograma(file, list_not)
        results_simple_dfs = simple_dataset_flujograma(result_df_list, file )
        final_df = combined_dataset(results_simple_dfs)
            
        all_combined_data.append(final_df)
        # print(f"  - Total filas del archivo: {len(file_combined)}")

    # Combinar todos los archivos
    if all_combined_data:
        final_data = pd.concat(all_combined_data, ignore_index=True)
        
        # Guardar como CSV
        final_data.to_csv(name_file, index=False)
        
        print(f"\nDataset final guardado: {name_file}")
        print(f" Total archivos procesados: {len(files)}")
        print(f" Total filas: {len(final_data)}")
        print(f" Total columnas: {len(final_data.columns)}")
        
        return final_data
    else:
        print("No se pudieron procesar los archivos")
        return None

# %%
# Borrador

# Borrador - Verificar coordenadas primero
excel_f = "/home/jazmin/Escritorio/AlertaVIAl/BD_InnovaThon/Flujograma_intersecciones/58_SS77-01_Av. Rosa Lozano-Jr. Geranios_Día_Atípico..xlsx"
list_not = ["Inicio", 'V_Ma', "V_Md", 'Ciclo Semaforico', 'Para Vissim']

# %%
datas = flujograma_concat_excels("../../BD_InnovaThon/Flujograma_intersecciones/*.xlsx", "dataset_flujograma.xlsx", list_not)
print(datas)
# Out:
# Archivos encontrados: 28
# Archivos: ['../../BD_InnovaThon/Flujograma_intersecciones/61_SS34-01_Av. Los Próceres - Ingreso A La Cruceta_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/58_SS77-01_Av. Rosa Lozano-Jr. Geranios_Día_Típico..xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP08 Av. Pachacutec - Av. Pardo_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP09 Av. Pachacutec -  Av. 26 de Noviembre _Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/58_SS77-01_Av. Rosa Lozano-Jr. Geranios_Día_Atípico..xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP02 Av. Los Héroes - Ca. Buckinghan_Día_Tipico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP06 Av. Pachacutec - Jr. Huamachuco - Av. 1_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP07 Av. Pachacutec -  8 de Octubre - Huayna Capac_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP01 Av. Los Héroes - Ca. Los Conquistadores_Día_Tipico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP09 Av. Pachacutec -  Av. 26 de Noviembre _Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP03 Av. Los Héroes - Av. San Juan_Día_Tipico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP07 Av. Pachacutec -  8 de Octubre - Huayna Capac_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP06 Av. Pachacutec - Jr. Huamachuco - Av. 1_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP01 Av. Los Héroes - Ca. Los Conquistadores_Día_Atipico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/62_SS35-01_Av. Los Próceres - Alt ESSALUD_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP04  Av. Los Héroes - Av. Miguel Iglesias_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/61_SS34-01_Av. Los Próceres - Ingreso A La Cruceta_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/59_SS78-01_ Av. Rosa Lozano - Jr. Cerro Gris_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP05 Av. Pachacutec -Av. Parado de Bellido_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP02 Av. Los Héroes - Ca. Buckinghan_Día_Atipico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/63_SS36-01_ Av. Próceres - Av. Paseo de la Repúbica_Día_Típico..xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP05 Av. Pachacutec -Av. Parado de Bellido_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP08 Av. Pachacutec - Av. Pardo_Día_Atípico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/62_SS35-01_Av. Los Próceres - Alt ESSALUD_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/59_SS78-01_ Av. Rosa Lozano - Jr. Cerro Gris_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP04  Av. Los Héroes - Av. Miguel Iglesias_Día_Típico.xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/63_SS36-01_ Av. Próceres - Av. Paseo de la Repúbica_Día_Atípico..xlsx', '../../BD_InnovaThon/Flujograma_intersecciones/SP03 Av. Los Héroes - Av. San Juan_Día_Atipico.xlsx']
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/61_SS34-01_Av. Los Próceres - Ingreso A La Cruceta_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=208.0
#   Fila 43: hora='', suma=209.0
#   Fila 44: hora='', suma=223.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 17081.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=494.0
#   Fila 43: hora='', suma=536.0
#   Fila 44: hora='', suma=517.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 22545.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=75.0
#   Fila 43: hora='', suma=74.0
#   Fila 44: hora='', suma=61.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 4309.0
# Archivo parseado: 61_SS34-01_Av. Los Próceres - Ingreso A La Cruceta_Día_Atípico.xlsx
#   Código: '61'
#   Intersección: 'SS34-01 Av. Los Próceres - Ingreso A La Cruceta Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/58_SS77-01_Av. Rosa Lozano-Jr. Geranios_Día_Típico..xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=340.0
#   Fila 43: hora='', suma=311.0
#   Fila 44: hora='', suma=365.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 13023.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=360.0
#   Fila 43: hora='', suma=297.0
#   Fila 44: hora='', suma=260.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 7067.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=80.0
#   Fila 43: hora='', suma=81.0
#   Fila 44: hora='', suma=106.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 2333.0
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=56.0
#   Fila 43: hora='', suma=48.0
#   Fila 44: hora='', suma=44.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 2069.0
# Archivo parseado: 58_SS77-01_Av. Rosa Lozano-Jr. Geranios_Día_Típico..xlsx
#   Código: '58'
#   Intersección: 'SS77-01 Av. Rosa Lozano-Jr. Geranios Típico.'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP08 Av. Pachacutec - Av. Pardo_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'NORTE', 'SUR', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=8.0
#   Fila 43: hora='', suma=8.0
#   Fila 44: hora='', suma=8.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 228.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=34.0
#   Fila 43: hora='', suma=38.0
#   Fila 44: hora='', suma=41.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1268.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=228.0
#   Fila 43: hora='', suma=287.0
#   Fila 44: hora='', suma=309.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 6013.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=212.0
#   Fila 43: hora='', suma=208.0
#   Fila 44: hora='', suma=246.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 6113.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
#
# Procesando hoja: NORTE
# Forma total: (58, 78)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=78
#
# Procesando hoja: SUR
# Forma total: (58, 34)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=34
# Archivo parseado: SP08 Av. Pachacutec - Av. Pardo_Día_Típico.xlsx
#   Código: 'SP08'
#   Intersección: 'Av. Pachacutec - Av. Pardo Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP09 Av. Pachacutec -  Av. 26 de Noviembre _Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=66.0
#   Fila 43: hora='', suma=98.0
#   Fila 44: hora='', suma=93.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2021.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=40.0
#   Fila 43: hora='', suma=46.0
#   Fila 44: hora='', suma=49.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1161.0
#
# Procesando hoja: E
# Forma total: (180, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=140
#   Fila 43: hora='', suma=90
#   Fila 44: hora='', suma=81
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2201
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=79
#   Fila 43: hora='', suma=67
#   Fila 44: hora='', suma=94
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1916
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP09 Av. Pachacutec -  Av. 26 de Noviembre _Día_Atípico.xlsx
#   Código: 'SP09'
#   Intersección: 'Av. Pachacutec - Av. 26 de Noviembre Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/58_SS77-01_Av. Rosa Lozano-Jr. Geranios_Día_Atípico..xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=384.0
#   Fila 43: hora='', suma=386.0
#   Fila 44: hora='', suma=408.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 16335.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=342.0
#   Fila 43: hora='', suma=331.0
#   Fila 44: hora='', suma=270.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 9342.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=66.0
#   Fila 43: hora='', suma=71.0
#   Fila 44: hora='', suma=84.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 2634.0
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=39.0
#   Fila 43: hora='', suma=48.0
#   Fila 44: hora='', suma=40.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 2442.0
# Archivo parseado: 58_SS77-01_Av. Rosa Lozano-Jr. Geranios_Día_Atípico..xlsx
#   Código: '58'
#   Intersección: 'SS77-01 Av. Rosa Lozano-Jr. Geranios Atípico.'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP02 Av. Los Héroes - Ca. Buckinghan_Día_Tipico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=30.0
#   Fila 43: hora='', suma=30.0
#   Fila 44: hora='', suma=34.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 557.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=72.0
#   Fila 43: hora='', suma=82.0
#   Fila 44: hora='', suma=91.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2313.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=302.0
#   Fila 43: hora='', suma=367.0
#   Fila 44: hora='', suma=318.0
#  Extraídas 26 filas válidas
#  Suma total de vehículos: 6861.133211678833
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=186.0
#   Fila 43: hora='', suma=214.0
#   Fila 44: hora='', suma=191.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 5637.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP02 Av. Los Héroes - Ca. Buckinghan_Día_Tipico.xlsx
#   Código: 'SP02'
#   Intersección: 'Av. Los Héroes - Ca. Buckinghan Tipico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP06 Av. Pachacutec - Jr. Huamachuco - Av. 1_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=214.0
#   Fila 43: hora='', suma=169.0
#   Fila 44: hora='', suma=205.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4301.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=395.0
#   Fila 43: hora='', suma=420.0
#   Fila 44: hora='', suma=475.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 7821.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=26.0
#   Fila 43: hora='', suma=30.0
#   Fila 44: hora='', suma=24.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 864.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP06 Av. Pachacutec - Jr. Huamachuco - Av. 1_Día_Típico.xlsx
#   Código: 'SP06'
#   Intersección: 'Av. Pachacutec - Jr. Huamachuco - Av. 1 Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP07 Av. Pachacutec -  8 de Octubre - Huayna Capac_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=66.0
#   Fila 43: hora='', suma=65.0
#   Fila 44: hora='', suma=58.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1599.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: E
# Forma total: (145, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=334.0
#   Fila 43: hora='', suma=332.0
#   Fila 44: hora='', suma=312.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 7105.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=199.0
#   Fila 43: hora='', suma=210.0
#   Fila 44: hora='', suma=141.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4965.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP07 Av. Pachacutec -  8 de Octubre - Huayna Capac_Día_Típico.xlsx
#   Código: 'SP07'
#   Intersección: 'Av. Pachacutec - 8 de Octubre - Huayna Capac Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP01 Av. Los Héroes - Ca. Los Conquistadores_Día_Tipico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ta', 'Flujograma Vehivular', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=25.0
#   Fila 43: hora='', suma=31.0
#   Fila 44: hora='', suma=31.0
#  Extraídas 46 filas válidas
#  Suma total de vehículos: 1034.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=454.0
#   Fila 43: hora='', suma=507.0
#   Fila 44: hora='', suma=528.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 9605.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=236.0
#   Fila 43: hora='', suma=266.0
#   Fila 44: hora='', suma=284.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 7750.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
#
# Procesando hoja: Flujograma Vehivular
# Forma total: (26, 67)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=26, cols=67
# Archivo parseado: SP01 Av. Los Héroes - Ca. Los Conquistadores_Día_Tipico.xlsx
#   Código: 'SP01'
#   Intersección: 'Av. Los Héroes - Ca. Los Conquistadores Tipico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP09 Av. Pachacutec -  Av. 26 de Noviembre _Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=119.0
#   Fila 43: hora='', suma=172.0
#   Fila 44: hora='', suma=168.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3604.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=77.0
#   Fila 43: hora='', suma=88.0
#   Fila 44: hora='', suma=95.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2180.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=262.0
#   Fila 43: hora='', suma=180.0
#   Fila 44: hora='', suma=160.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4272.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=149.0
#   Fila 43: hora='', suma=129.0
#   Fila 44: hora='', suma=178.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3568.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP09 Av. Pachacutec -  Av. 26 de Noviembre _Día_Típico.xlsx
#   Código: 'SP09'
#   Intersección: 'Av. Pachacutec - Av. 26 de Noviembre Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP03 Av. Los Héroes - Av. San Juan_Día_Tipico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'Esquema de flujos', 'V_Md', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=139.0
#   Fila 43: hora='', suma=160.0
#   Fila 44: hora='', suma=178.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2804.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=258.0
#   Fila 43: hora='', suma=304.0
#   Fila 44: hora='', suma=259.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 5206.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=271.0
#   Fila 43: hora='', suma=286.0
#   Fila 44: hora='', suma=259.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4753.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=243.0
#   Fila 43: hora='', suma=209.0
#   Fila 44: hora='', suma=175.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4923.0
#
# Procesando hoja: Esquema de flujos
# Forma total: (0, 0)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=0, cols=0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP03 Av. Los Héroes - Av. San Juan_Día_Tipico.xlsx
#   Código: 'SP03'
#   Intersección: 'Av. Los Héroes - Av. San Juan Tipico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP07 Av. Pachacutec -  8 de Octubre - Huayna Capac_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=34.0
#   Fila 43: hora='', suma=35.0
#   Fila 44: hora='', suma=30.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 838.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=191
#   Fila 43: hora='', suma=194
#   Fila 44: hora='', suma=180
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4105
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=96
#   Fila 43: hora='', suma=100
#   Fila 44: hora='', suma=70
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2426
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP07 Av. Pachacutec -  8 de Octubre - Huayna Capac_Día_Atípico.xlsx
#   Código: 'SP07'
#   Intersección: 'Av. Pachacutec - 8 de Octubre - Huayna Capac Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP06 Av. Pachacutec - Jr. Huamachuco - Av. 1_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=121.0
#   Fila 43: hora='', suma=93.0
#   Fila 44: hora='', suma=117.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2433.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=227.0
#   Fila 43: hora='', suma=243.0
#   Fila 44: hora='', suma=275.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4489.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=13.0
#   Fila 43: hora='', suma=15.0
#   Fila 44: hora='', suma=12.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 460.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP06 Av. Pachacutec - Jr. Huamachuco - Av. 1_Día_Atípico.xlsx
#   Código: 'SP06'
#   Intersección: 'Av. Pachacutec - Jr. Huamachuco - Av. 1 Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP01 Av. Los Héroes - Ca. Los Conquistadores_Día_Atipico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'Flujograma Vehivular', 'V_Ta', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=6.0
#   Fila 43: hora='', suma=8.0
#   Fila 44: hora='', suma=10.0
#  Extraídas 26 filas válidas
#  Suma total de vehículos: 316.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=412.0
#   Fila 43: hora='', suma=422.0
#   Fila 44: hora='', suma=384.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 9632.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=226.0
#   Fila 43: hora='', suma=254.0
#   Fila 44: hora='', suma=248.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 7449.0
#
# Procesando hoja: Flujograma Vehivular
# Forma total: (26, 67)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=26, cols=67
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP01 Av. Los Héroes - Ca. Los Conquistadores_Día_Atipico.xlsx
#   Código: 'SP01'
#   Intersección: 'Av. Los Héroes - Ca. Los Conquistadores Atipico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/62_SS35-01_Av. Los Próceres - Alt ESSALUD_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=107.0
#   Fila 43: hora='', suma=108.0
#   Fila 44: hora='', suma=94.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 7427.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=317.0
#   Fila 43: hora='', suma=365.0
#   Fila 44: hora='', suma=376.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 17117.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
# Archivo parseado: 62_SS35-01_Av. Los Próceres - Alt ESSALUD_Día_Atípico.xlsx
#   Código: '62'
#   Intersección: 'SS35-01 Av. Los Próceres - Alt ESSALUD Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP04  Av. Los Héroes - Av. Miguel Iglesias_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=79
#   Fila 43: hora='', suma=82
#   Fila 44: hora='', suma=89
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1735
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=116.0
#   Fila 43: hora='', suma=114.0
#   Fila 44: hora='', suma=95.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2888.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=114.0
#   Fila 43: hora='', suma=95.0
#   Fila 44: hora='', suma=119.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2303.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=91
#   Fila 43: hora='', suma=80
#   Fila 44: hora='', suma=102
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2180
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP04  Av. Los Héroes - Av. Miguel Iglesias_Día_Atípico.xlsx
#   Código: 'SP04'
#   Intersección: 'Av. Los Héroes - Av. Miguel Iglesias Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/61_SS34-01_Av. Los Próceres - Ingreso A La Cruceta_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=270.0
#   Fila 43: hora='', suma=326.0
#   Fila 44: hora='', suma=330.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 16827.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=827.0
#   Fila 43: hora='', suma=993.0
#   Fila 44: hora='', suma=1027.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 23798.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=136.0
#   Fila 43: hora='', suma=116.0
#   Fila 44: hora='', suma=134.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 3412.0
# Archivo parseado: 61_SS34-01_Av. Los Próceres - Ingreso A La Cruceta_Día_Típico.xlsx
#   Código: '61'
#   Intersección: 'SS34-01 Av. Los Próceres - Ingreso A La Cruceta Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/59_SS78-01_ Av. Rosa Lozano - Jr. Cerro Gris_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=337.0
#   Fila 43: hora='', suma=347.0
#   Fila 44: hora='', suma=357.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 17628.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=468.0
#   Fila 43: hora='', suma=461.0
#   Fila 44: hora='', suma=355.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 11566.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=10.0
#   Fila 43: hora='', suma=15.0
#   Fila 44: hora='', suma=10.0
#  Extraídas 35 filas válidas
#  Suma total de vehículos: 489.0
# Archivo parseado: 59_SS78-01_ Av. Rosa Lozano - Jr. Cerro Gris_Día_Atípico.xlsx
#   Código: '59'
#   Intersección: 'SS78-01 Av. Rosa Lozano - Jr. Cerro Gris Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP05 Av. Pachacutec -Av. Parado de Bellido_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'NORTE', 'SUR', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=269.0
#   Fila 43: hora='', suma=234.0
#   Fila 44: hora='', suma=231.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 6697.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=144.0
#   Fila 43: hora='', suma=186.0
#   Fila 44: hora='', suma=130.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3688.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=52.0
#   Fila 43: hora='', suma=55.0
#   Fila 44: hora='', suma=50.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1648.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=12.0
#   Fila 43: hora='', suma=14.0
#   Fila 44: hora='', suma=12.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 317.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
#
# Procesando hoja: NORTE
# Forma total: (58, 78)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=78
#
# Procesando hoja: SUR
# Forma total: (58, 34)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=34
# Archivo parseado: SP05 Av. Pachacutec -Av. Parado de Bellido_Día_Típico.xlsx
#   Código: 'SP05'
#   Intersección: 'Av. Pachacutec -Av. Parado de Bellido Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP02 Av. Los Héroes - Ca. Buckinghan_Día_Atipico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=16.0
#   Fila 43: hora='', suma=17.0
#   Fila 44: hora='', suma=19.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 299.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=44.0
#   Fila 43: hora='', suma=52.0
#   Fila 44: hora='', suma=59.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1487.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=202
#   Fila 43: hora='', suma=246
#   Fila 44: hora='', suma=212
#  Extraídas 23 filas válidas
#  Suma total de vehículos: 4552
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=108
#   Fila 43: hora='', suma=131
#   Fila 44: hora='', suma=113
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3493
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP02 Av. Los Héroes - Ca. Buckinghan_Día_Atipico.xlsx
#   Código: 'SP02'
#   Intersección: 'Av. Los Héroes - Ca. Buckinghan Atipico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/63_SS36-01_ Av. Próceres - Av. Paseo de la Repúbica_Día_Típico..xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=450.0
#   Fila 43: hora='', suma=506.0
#   Fila 44: hora='', suma=571.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 21888.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=587.0
#   Fila 43: hora='', suma=533.0
#   Fila 44: hora='', suma=551.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 14979.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=251.0
#   Fila 43: hora='', suma=281.0
#   Fila 44: hora='', suma=274.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 7920.0
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=208.0
#   Fila 43: hora='', suma=278.0
#   Fila 44: hora='', suma=214.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 6991.0
# Archivo parseado: 63_SS36-01_ Av. Próceres - Av. Paseo de la Repúbica_Día_Típico..xlsx
#   Código: '63'
#   Intersección: 'SS36-01 Av. Próceres - Av. Paseo de la Repúbica Típico.'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP05 Av. Pachacutec -Av. Parado de Bellido_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'NORTE', 'SUR', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=164
#   Fila 43: hora='', suma=143
#   Fila 44: hora='', suma=144
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4105
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=79
#   Fila 43: hora='', suma=103
#   Fila 44: hora='', suma=68
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 2026
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=36
#   Fila 43: hora='', suma=36
#   Fila 44: hora='', suma=33
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1028
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=5
#   Fila 43: hora='', suma=6
#   Fila 44: hora='', suma=6
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 145
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
#
# Procesando hoja: NORTE
# Forma total: (58, 78)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=78
#
# Procesando hoja: SUR
# Forma total: (58, 34)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=34
# Archivo parseado: SP05 Av. Pachacutec -Av. Parado de Bellido_Día_Atípico.xlsx
#   Código: 'SP05'
#   Intersección: 'Av. Pachacutec -Av. Parado de Bellido Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP08 Av. Pachacutec - Av. Pardo_Día_Atípico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'NORTE', 'SUR', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=2.0
#   Fila 43: hora='', suma=3.0
#   Fila 44: hora='', suma=3.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 77.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=20.0
#   Fila 43: hora='', suma=19.0
#   Fila 44: hora='', suma=24.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 688.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=129
#   Fila 43: hora='', suma=161
#   Fila 44: hora='', suma=175
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3405
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=121
#   Fila 43: hora='', suma=116
#   Fila 44: hora='', suma=141
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3523
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
#
# Procesando hoja: NORTE
# Forma total: (58, 78)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=78
#
# Procesando hoja: SUR
# Forma total: (58, 34)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=58, cols=34
# Archivo parseado: SP08 Av. Pachacutec - Av. Pardo_Día_Atípico.xlsx
#   Código: 'SP08'
#   Intersección: 'Av. Pachacutec - Av. Pardo Atípico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/62_SS35-01_Av. Los Próceres - Alt ESSALUD_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=107.0
#   Fila 43: hora='', suma=124.0
#   Fila 44: hora='', suma=116.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 7288.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=520.0
#   Fila 43: hora='', suma=570.0
#   Fila 44: hora='', suma=534.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 17578.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
# Archivo parseado: 62_SS35-01_Av. Los Próceres - Alt ESSALUD_Día_Típico.xlsx
#   Código: '62'
#   Intersección: 'SS35-01 Av. Los Próceres - Alt ESSALUD Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/59_SS78-01_ Av. Rosa Lozano - Jr. Cerro Gris_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=314.0
#   Fila 43: hora='', suma=309.0
#   Fila 44: hora='', suma=305.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 16196.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=511.0
#   Fila 43: hora='', suma=421.0
#   Fila 44: hora='', suma=393.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 10092.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=13.0
#   Fila 43: hora='', suma=12.0
#   Fila 44: hora='', suma=25.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 565.0
# Archivo parseado: 59_SS78-01_ Av. Rosa Lozano - Jr. Cerro Gris_Día_Típico.xlsx
#   Código: '59'
#   Intersección: 'SS78-01 Av. Rosa Lozano - Jr. Cerro Gris Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP04  Av. Los Héroes - Av. Miguel Iglesias_Día_Típico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=162.0
#   Fila 43: hora='', suma=159.0
#   Fila 44: hora='', suma=180.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3548.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=245.0
#   Fila 43: hora='', suma=241.0
#   Fila 44: hora='', suma=196.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 5966.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=205.0
#   Fila 43: hora='', suma=169.0
#   Fila 44: hora='', suma=212.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 4168.0
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=166.0
#   Fila 43: hora='', suma=145.0
#   Fila 44: hora='', suma=176.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3953.0
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP04  Av. Los Héroes - Av. Miguel Iglesias_Día_Típico.xlsx
#   Código: 'SP04'
#   Intersección: 'Av. Los Héroes - Av. Miguel Iglesias Típico'
#   Es atípico: False
#   Día tipo: Típico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/63_SS36-01_ Av. Próceres - Av. Paseo de la Repúbica_Día_Atípico..xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (136, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=339.0
#   Fila 43: hora='', suma=362.0
#   Fila 44: hora='', suma=344.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 21592.0
#
# Procesando hoja: S
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=450.0
#   Fila 43: hora='', suma=458.0
#   Fila 44: hora='', suma=454.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 16441.0
#
# Procesando hoja: E
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=197.0
#   Fila 43: hora='', suma=232.0
#   Fila 44: hora='', suma=215.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 8779.0
#
# Procesando hoja: O
# Forma total: (130, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=116.0
#   Fila 43: hora='', suma=108.0
#   Fila 44: hora='', suma=155.0
#  Extraídas 36 filas válidas
#  Suma total de vehículos: 6268.0
# Archivo parseado: 63_SS36-01_ Av. Próceres - Av. Paseo de la Repúbica_Día_Atípico..xlsx
#   Código: '63'
#   Intersección: 'SS36-01 Av. Próceres - Av. Paseo de la Repúbica Atípico.'
#   Es atípico: True
#   Día tipo: Atípico
#
# Procesando archivo: ../../BD_InnovaThon/Flujograma_intersecciones/SP03 Av. Los Héroes - Av. San Juan_Día_Atipico.xlsx
# Hojas encontradas: ['Inicio', 'N', 'S', 'E', 'O', 'V_Md', 'V_Ma', 'V_Ta', 'Ciclo Semaforico', 'Para Vissim']
#
# Procesando hoja: N
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=97.0
#   Fila 43: hora='', suma=114.0
#   Fila 44: hora='', suma=124.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 1994.0
#
# Procesando hoja: S
# Forma total: (127, 245)
# Región extraída: (56, 104)
#   Fila 42: hora='', suma=182.0
#   Fila 43: hora='', suma=215.0
#   Fila 44: hora='', suma=181.0
#  Extraídas 22 filas válidas
#  Suma total de vehículos: 3720.0
#
# Procesando hoja: E
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: O
# Forma total: (127, 245)
# Región extraída: (56, 104)
#  No se encontraron datos válidos
#
# Procesando hoja: V_Ta
# Forma total: (108, 83)
#  Dimensiones insuficientes. Necesario: filas>96, cols>113
#   Actual: filas=108, cols=83
# Archivo parseado: SP03 Av. Los Héroes - Av. San Juan_Día_Atipico.xlsx
#   Código: 'SP03'
#   Intersección: 'Av. Los Héroes - Av. San Juan Atipico'
#   Es atípico: True
#   Día tipo: Atípico
#
# Dataset final guardado: dataset_flujograma.xlsx
#  Total archivos procesados: 28
#  Total filas: 28
#  Total columnas: 8
#                                          interseccion dia_tipo  \
# 0   SS34-01 Av. Los Próceres - Ingreso A La Crucet...  Atípico
# 1        SS77-01 Av. Rosa Lozano-Jr. Geranios Típico.   Típico
# 2                   Av. Pachacutec - Av. Pardo Típico   Típico
# 3        Av. Pachacutec - Av. 26 de Noviembre Atípico  Atípico
# 4       SS77-01 Av. Rosa Lozano-Jr. Geranios Atípico.  Atípico
# 5              Av. Los Héroes - Ca. Buckinghan Tipico   Típico
# 6      Av. Pachacutec - Jr. Huamachuco - Av. 1 Típico   Típico
# 7   Av. Pachacutec - 8 de Octubre - Huayna Capac T...   Típico
# 8      Av. Los Héroes - Ca. Los Conquistadores Tipico   Típico
# 9         Av. Pachacutec - Av. 26 de Noviembre Típico   Típico
# 10               Av. Los Héroes - Av. San Juan Tipico   Típico
# 11  Av. Pachacutec - 8 de Octubre - Huayna Capac A...  Atípico
# 12    Av. Pachacutec - Jr. Huamachuco - Av. 1 Atípico  Atípico
# 13    Av. Los Héroes - Ca. Los Conquistadores Atipico  Atípico
# 14     SS35-01 Av. Los Próceres - Alt ESSALUD Atípico  Atípico
# 15       Av. Los Héroes - Av. Miguel Iglesias Atípico  Atípico
# 16  SS34-01 Av. Los Próceres - Ingreso A La Crucet...   Típico
# 17   SS78-01 Av. Rosa Lozano - Jr. Cerro Gris Atípico  Atípico
# 18       Av. Pachacutec -Av. Parado de Bellido Típico   Típico
# 19            Av. Los Héroes - Ca. Buckinghan Atipico  Atípico
# 20  SS36-01 Av. Próceres - Av. Paseo de la Repúbic...   Típico
# 21      Av. Pachacutec -Av. Parado de Bellido Atípico  Atípico
# 22                 Av. Pachacutec - Av. Pardo Atípico  Atípico
# 23      SS35-01 Av. Los Próceres - Alt ESSALUD Típico   Típico
# 24    SS78-01 Av. Rosa Lozano - Jr. Cerro Gris Típico   Típico
# 25        Av. Los Héroes - Av. Miguel Iglesias Típico   Típico
# 26  SS36-01 Av. Próceres - Av. Paseo de la Repúbic...  Atípico
# 27              Av. Los Héroes - Av. San Juan Atipico  Atípico
#
#     suma_vehiculos_N  suma_vehiculos_S  suma_vehiculos_E  suma_vehiculos_O  \
# 0              208.0             494.0               0.0              75.0
# 1              340.0             360.0              80.0              56.0
# 2                8.0              34.0             228.0             212.0
# 3               66.0              40.0             140.0              79.0
# 4              384.0             342.0              66.0              39.0
# 5               30.0              72.0             302.0             186.0
# 6              214.0             395.0               0.0              26.0
# 7               66.0               0.0             334.0             199.0
# 8                0.0              25.0             454.0             236.0
# 9              119.0              77.0             262.0             149.0
# 10             139.0             258.0             271.0             243.0
# 11              34.0               0.0             191.0              96.0
# 12             121.0             227.0               0.0              13.0
# 13               0.0               6.0             412.0             226.0
# 14             107.0             317.0               0.0               0.0
# 15              79.0             116.0             114.0              91.0
# 16             270.0             827.0               0.0             136.0
# 17             337.0             468.0               0.0              10.0
# 18             269.0             144.0              52.0              12.0
# 19              16.0              44.0             202.0             108.0
# 20             450.0             587.0             251.0             208.0
# 21             164.0              79.0              36.0               5.0
# 22               2.0              20.0             129.0             121.0
# 23             107.0             520.0               0.0               0.0
# 24             314.0             511.0               0.0              13.0
# 25             162.0             245.0             205.0             166.0
# 26             339.0             450.0             197.0             116.0
# 27              97.0             182.0               0.0               0.0
#
#    hora_inicio hora_fin
# 0        06:30    06:45
# 1        06:30    06:45
# 2        06:30    06:45
# 3        06:30    06:45
# 4        06:30    06:45
# 5        06:30    06:45
# 6        06:30    06:45
# 7        06:30    06:45
# 8        06:30    06:45
# 9        06:30    06:45
# 10       06:30    06:45
# 11       06:30    06:45
# 12       06:30    06:45
# 13       06:30    06:45
# 14       06:30    06:45
# 15       06:30    06:45
# 16       06:30    06:45
# 17       06:30    06:45
# 18       06:30    06:45
# 19       06:30    06:45
# 20       06:30    06:45
# 21       06:30    06:45
# 22       06:30    06:45
# 23       06:30    06:45
# 24       06:30    06:45
# 25       06:30    06:45
# 26       06:30    06:45
# 27       06:30    06:45
